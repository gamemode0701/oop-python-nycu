# %% [markdown]
# # Pandas

# %%
import pandas as pd

# Create a sample DataFrame
data = {'name': ['Alice', 'Bob', 'Charlie', 'David'],
        'age': [25, 30, 35, None],
        'salary': [50000, 60000, 75000, 65000]}
df = pd.DataFrame(data)

# Display basic info
print("DataFrame Info:")
print(df.info())

# Handle missing values
df['age'].fillna(df['age'].mean(), inplace=True)

# Filter employees with salary > 60000
high_earners = df[df['salary'] > 60000]
print("\nHigh Earners:")
print(high_earners)

# Group by age and calculate average salary
avg_salary_by_age = df.groupby('age')['salary'].mean()
print("\nAverage Salary by Age:")
print(avg_salary_by_age)

# Save to CSV
df.to_csv('employees.csv', index=False)
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     3 non-null      float64
#  2   salary  4 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes
# None
#
# High Earners:
#       name   age  salary
# 2  Charlie  35.0   75000
# 3    David  30.0   65000
#
# Average Salary by Age:
# age
# 25.0    50000.0
# 30.0    62500.0
# 35.0    75000.0
# Name: salary, dtype: float64
# /tmp/ipykernel_68662/145801511.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure with two subplots
plt.figure(figsize=(10, 5))

# First subplot: Sine wave
plt.subplot(1, 2, 1)
plt.plot(x, y1, color='blue', label='sin(x)')
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.legend()
plt.grid(True)

# Second subplot: Cosine wave
plt.subplot(1, 2, 2)
plt.plot(x, y2, color='red', label='cos(x)')
plt.title('Cosine Wave')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.legend()
plt.grid(True)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pratice yourself!

# %%
# 1. 讀取資料
# Your code here  # 讀取 sales_data.csv
df = pd.read_csv('sales_data.csv')  
# print("Df info", df.info)

# 2. 新增 Total_Sales 欄位（Quantity × Price）
# Your code here  # 計算每筆交易的總銷售額
df['Total_Sales'] = df["Quantity"] * df["Price"]
print(df.info)

# 3. 按 Category 分組，計算總銷售額和總數量
category_summary = df.groupby("Product")[['Total_Sales', 'Quantity']].sum()  # 分組並計算總和
print("類別總結：\n", category_summary)

# 4. 找出銷售額最高的產品
# Your code here  # 按產品分組，找出銷售額最高的產品
top_product = category_summary['Total_Sales'].idxmax()
# Your code here  # 計算最高銷售額
top_sales = category_summary['Total_Sales'].max()
print(f"銷售額最高的產品是: {top_product}，總銷售額: {top_sales}")

# 5. 繪製柱狀圖：每個產品的總銷售額
plt.figure(figsize=(10, 5))  # 設定圖表大小
product_sales = df.groupby('Product')['Total_Sales'].sum()  # 按產品分組計算總銷售額
plt.bar(product_sales.index, product_sales.values , color='skyblue')  # 繪製柱狀圖
plt.title("The total sale of every procduct")  # 圖表標題
plt.xlabel("Products")  # x 軸標籤
plt.ylabel("Sales")  # y 軸標籤
plt.savefig('sales_by_product.png')
plt.show()

# 6. 繪製折線圖：每天的總銷售額
daily_sales = df.groupby('Date')['Total_Sales'].sum()  # 按日期分組計算總銷售額
plt.figure(figsize=(10, 5))  # 設定圖表大小
plt.plot(daily_sales.index, daily_sales.values, marker='o', color='orange')  # 繪製折線圖
plt.title('Sales variation by dates')  # 圖表標題
plt.xlabel('Dates')  # x 軸標籤
plt.ylabel('Sales per day')  # y 軸標籤
plt.xticks(rotation=45)  # 旋轉 x 軸標籤
plt.savefig('daily_sales_trend.png')
plt.show()
# Out:
# <bound method DataFrame.info of           Date     Product     Category  Quantity  Price  Total_Sales
# 0   2023-01-01      Laptop  Electronics         5   1000         5000
# 1   2023-01-01       Mouse  Electronics        10     20          200
# 2   2023-01-01        Desk    Furniture         3    150          450
# 3   2023-01-02      Laptop  Electronics         3   1000         3000
# 4   2023-01-02    Keyboard  Electronics         8     50          400
# 5   2023-01-02       Chair    Furniture         2    100          200
# 6   2023-01-03       Mouse  Electronics        15     20          300
# 7   2023-01-03        Desk    Furniture         1    150          150
# 8   2023-01-04      Laptop  Electronics         7   1000         7000
# 9   2023-01-04  Headphones  Electronics         4     80          320
# 10  2023-01-05    Keyboard  Electronics         6     50          300
# 11  2023-01-05       Table    Furniture         2    200          400
# 12  2023-01-05       Mouse  Electronics        12     20          240
# 13  2023-01-06      Laptop  Electronics         4   1000         4000
# 14  2023-01-06  Headphones  Electronics         5     80          400
# 15  2023-01-06       Chair    Furniture         3    100          300>
# 類別總結：
#              Total_Sales  Quantity
# Product
# Chair               500         5
# Desk                600         4
# Headphones          720         9
# Keyboard            700        14
# Laptop            19000        19
# Mouse               740        37
# Table               400         2
# 銷售額最高的產品是: Laptop，總銷售額: 19000
